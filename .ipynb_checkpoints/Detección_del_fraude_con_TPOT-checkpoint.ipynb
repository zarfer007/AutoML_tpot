# %% [markdown]
# ##1 Descarga de librerias

# %%
# !pip install tpot
# Out:
# Requirement already satisfied: tpot in /Users/fernando/miniconda3/lib/python3.8/site-packages (0.11.6.post3)
# Requirement already satisfied: numpy>=1.16.3 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (1.19.2)
# Requirement already satisfied: pandas>=0.24.2 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (1.1.5)
# Requirement already satisfied: joblib>=0.13.2 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (1.0.0)
# Requirement already satisfied: deap>=1.2 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (1.3.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (0.23.2)
# Requirement already satisfied: update-checker>=0.16 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (0.18.0)
# Requirement already satisfied: stopit>=1.1.1 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (1.1.2)
# Requirement already satisfied: tqdm>=4.36.1 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (4.46.0)
# Requirement already satisfied: xgboost>=1.1.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (1.3.1)
# Requirement already satisfied: scipy>=1.3.1 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from tpot) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2020.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.0->tpot) (2.1.0)
# Requirement already satisfied: requests>=2.3.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from update-checker>=0.16->tpot) (2.23.0)
# Requirement already satisfied: six>=1.5 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.14.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)

# %%
# !python -m pip install dask distributed --upgrade
# Out:
# Requirement already up-to-date: dask in /Users/fernando/miniconda3/lib/python3.8/site-packages (2020.12.0)
# Requirement already up-to-date: distributed in /Users/fernando/miniconda3/lib/python3.8/site-packages (2020.12.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /Users/fernando/miniconda3/lib/python3.8/site-packages (from dask) (5.3.1)
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.5.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (1.6.0)
# Requirement already satisfied, skipping upgrade: click>=6.6 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (7.1.2)
# Requirement already satisfied, skipping upgrade: sortedcontainers!=2.0.0,!=2.0.1 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (2.3.0)
# Requirement already satisfied, skipping upgrade: setuptools in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (46.4.0.post20200518)
# Requirement already satisfied, skipping upgrade: zict>=0.1.3 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (2.0.0)
# Requirement already satisfied, skipping upgrade: tblib>=1.6.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (1.7.0)
# Requirement already satisfied, skipping upgrade: tornado>=6.0.3; python_version >= "3.8" in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (6.0.4)
# Requirement already satisfied, skipping upgrade: psutil>=5.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (5.8.0)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (0.11.1)
# Requirement already satisfied, skipping upgrade: msgpack>=0.6.0 in /Users/fernando/miniconda3/lib/python3.8/site-packages (from distributed) (1.0.2)
# Requirement already satisfied, skipping upgrade: heapdict in /Users/fernando/miniconda3/lib/python3.8/site-packages (from zict>=0.1.3->distributed) (1.0.1)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


from sklearn.model_selection import train_test_split

import time
import tpot # Added library
from tpot import TPOTClassifier

# %% [markdown]
# ## Data, original, groups

# %% [markdown]
# ### Reading kaggel data
#
# Github might be full if dowloading from it

# %%
# How to mount kaggle api in colab: 
# https://medium.com/analytics-vidhya/how-to-fetch-kaggle-datasets-into-google-colab-ea682569851a 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e857aa411d62> in <module>
#       1 # How to mount kaggle api in colab:
#       2 # https://medium.com/analytics-vidhya/how-to-fetch-kaggle-datasets-into-google-colab-ea682569851a
# ----> 3 from google.colab import drive
#       4 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google'

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive

#changing the working directory
# %cd /content/gdrive/My Drive/Kaggle
#Check the present working directory using pwd command

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# !ls

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip

# %%
#Reading the file
df= pd.read_csv('/content/gdrive/My Drive/Kaggle/creditcard.csv')
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-5472d07747de> in <module>
#       1 #Reading the file
# ----> 2 df= pd.read_csv('/content/gdrive/My Drive/Kaggle/creditcard.csv')
#       3 df.shape
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/Kaggle/creditcard.csv'

# %% [markdown]
# ## Reading from own linkry

# %%
#df = pd.read_csv('/content/creditcard.csv') # Emilio's link
df = pd.read_csv('~/Desktop/AutoML/creditcard.csv') # Fernando's link
df.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
# In order to compare amounts regarding their relative sizes
#display(df['Amount'].isnull().sum()) # none
df['Amount']= (np.log(df['Amount'])).replace([np.inf, -np.inf], np.nan)

fraudulent_data = df.loc[df['Class'] == 1]
nonfraudulent_data = df.loc[df['Class'] == 0]
# Out:
# /Users/fernando/miniconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# #2. Exploración de los datos

# %%
print('Groups and types',
      f'shape: {df.shape}',
      f'dtypes_aggregate: {df.dtypes.value_counts()}',
      f'fraud cases: {df.Class.sum()}',
      f'fraud cases (rate): {df.Class.sum()/df.shape[0]*100}',
      )

# There no duplicates
display(df.shape)
df.drop_duplicates()
display(df.shape)

print('How the infinites of log of Amount was distributed between groups')
display(df['Amount'].isna().sum(),
        fraudulent_data['Amount'].isna().sum(),
        nonfraudulent_data['Amount'].isna().sum())

display(df.head(3))
display(df.tail(3))
# Out:
# Groups and types shape: (284807, 31) dtypes_aggregate: float64    30
# int64       1
# dtype: int64 fraud cases: 492 fraud cases (rate): 0.1727485630620034
# (284807, 31)
# (284807, 31)
# How the infinites of log of Amount was distributed between groups
# 1825
# 27
# 1798
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28    Amount  Class
# 0 -0.189115  0.133558 -0.021053  5.008099      0
# 1  0.125895 -0.008983  0.014724  0.989541      0
# 2 -0.139097 -0.055353 -0.059752  5.936639      0
#
# [3 rows x 31 columns]
#             Time        V1        V2        V3        V4        V5        V6  \
# 284804  172788.0  1.919565 -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  172788.0 -0.240440  0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 284804 -0.296827  0.708417  0.432454  ...  0.232045  0.578229 -0.037501
# 284805 -0.686180  0.679145  0.392087  ...  0.265245  0.800049 -0.163298
# 284806  1.577006 -0.414650  0.486180  ...  0.261057  0.643078  0.376777
#
#              V24       V25       V26       V27       V28    Amount  Class
# 284804  0.640134  0.265745 -0.087371  0.004455 -0.026561  4.217741      0
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533  2.302585      0
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649  5.379897      0
#
# [3 rows x 31 columns]

# %%
display(df.describe(),
        fraudulent_data.describe(), nonfraudulent_data.describe())
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.656562e-16 -3.444850e-16  2.578648e-16  4.471968e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  282982.000000
# mean   5.340915e-16  1.687098e-15 -3.666453e-16 -1.220404e-16       3.005141
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01       1.870020
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01      -4.605170
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       1.790091
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02       3.113071
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02       4.356709
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01      10.153902
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# min    -22.105532   -6.406267  -43.557242  -41.044261  -13.434066  ...
# 25%     -4.792835   -2.501511   -7.965295   -0.195336   -3.872383  ...
# 50%     -1.522962   -1.424616   -3.034402    0.621508   -2.208768  ...
# 75%      0.214562   -0.413216   -0.945954    1.764879   -0.787850  ...
# max     11.095089    6.474115    5.802537   20.007208    3.353525  ...
#
#               V21         V22         V23         V24         V25         V26  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  492.000000
# mean     0.713588    0.014049   -0.040308   -0.105130    0.041449    0.051648
# std      3.869304    1.494602    1.579642    0.515577    0.797205    0.471679
# min    -22.797604   -8.887017  -19.254328   -2.028024   -4.781606   -1.152671
# 25%      0.041787   -0.533764   -0.342175   -0.436809   -0.314348   -0.259416
# 50%      0.592146    0.048434   -0.073135   -0.060795    0.088371    0.004321
# 75%      1.244611    0.617474    0.308378    0.285328    0.456515    0.396733
# max     27.202839    8.361985    5.466230    1.091435    2.208209    2.745261
#
#               V27         V28      Amount  Class
# count  492.000000  492.000000  465.000000  492.0
# mean     0.170575    0.075667    2.650593    1.0
# std      1.376766    0.547291    2.557035    0.0
# min     -7.263482   -1.869290   -4.605170    1.0
# 25%     -0.020025   -0.108868    0.000000    1.0
# 50%      0.394926    0.146344    2.836737    1.0
# 75%      0.826029    0.381152    4.715817    1.0
# max      3.052358    1.779364    7.661936    1.0
#
# [8 rows x 31 columns]
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# 25%        -0.850077      -0.689398      -0.766847      -0.551442
# 50%        -0.022405      -0.053457      -0.273123       0.041138
# 75%         0.737624       0.612181       0.399619       0.571019
# max        16.875344      34.801666      73.301626     120.589494
#
#                   V8             V9  ...            V21            V22  \
# count  284315.000000  284315.000000  ...  284315.000000  284315.000000
# mean       -0.000987       0.004467  ...      -0.001235      -0.000024
# std         1.161283       1.089372  ...       0.716743       0.723668
# min       -73.216718      -6.290730  ...     -34.830382     -10.933144
# 25%        -0.208633      -0.640412  ...      -0.228509      -0.542403
# 50%         0.022041      -0.049964  ...      -0.029821       0.006736
# 75%         0.326200       0.598230  ...       0.185626       0.528407
# max        18.709255      15.594995  ...      22.614889      10.503090
#
#                  V23            V24            V25            V26  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean        0.000070       0.000182      -0.000072      -0.000089
# std         0.621541       0.605776       0.520673       0.482241
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.161702      -0.354425      -0.317145      -0.327074
# 50%        -0.011147       0.041082       0.016417      -0.052227
# 75%         0.147522       0.439869       0.350594       0.240671
# max        22.528412       4.584549       7.519589       3.517346
#
#                  V27            V28         Amount     Class
# count  284315.000000  284315.000000  282517.000000  284315.0
# mean       -0.000295      -0.000131       3.005724       0.0
# std         0.399847       0.329570       1.868632       0.0
# min       -22.565679     -15.430084      -4.605170       0.0
# 25%        -0.070852      -0.052950       1.790091       0.0
# 50%         0.001230       0.011199       3.113071       0.0
# 75%         0.090573       0.077962       4.356709       0.0
# max        31.612198      33.847808      10.153902       0.0
#
# [8 rows x 31 columns]

# %%
# Multimodal (more modes for non-fraudulent data) and few highly values 
plt.figure(figsize=(18,6))
#sns.kdeplot(df['Amount'], shade=True, color="r")
sns.kdeplot(fraudulent_data['Amount'], shade=True, color="r")
sns.kdeplot(nonfraudulent_data['Amount'], shade=True, color="b")

plt.show()

# %%
plt.figure(figsize=(16,10))
plot = sns.distplot(a=df["Time"], kde=True, color='brown')
plot = sns.distplot(a=fraudulent_data["Time"], kde=True, color='purple')
plot = sns.distplot(a=nonfraudulent_data["Time"], kde=True, color='blue')

plot.set(xlabel ='Time', ylabel ='Frequency')
plt.show()
# Out:
# /Users/fernando/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/fernando/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/fernando/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Correlation between groups differs sharply
df_corr = {}
df_corr["correlation"] =abs(df.corr()['Amount']).sort_values(ascending=False)
df_corr["correlation_fraud"] =abs(fraudulent_data.corr()['Amount']).sort_values(ascending=False)
df_corr["correlation_nonfraud"] =abs(nonfraudulent_data.corr()['Amount']).sort_values(ascending=False)
display(df_corr)
df_corr= pd.DataFrame(df_corr)
df_corr
# Out:
# {'correlation': Amount    1.000000
#  V2        0.432917
#  V5        0.274332
#  V6        0.161623
#  V20       0.128475
#  V16       0.095224
#  V9        0.090543
#  V1        0.087004
#  V21       0.083550
#  V7        0.081907
#  V15       0.073558
#  V11       0.057399
#  V22       0.048649
#  V27       0.047584
#  V18       0.035539
#  Time      0.028724
#  V23       0.028194
#  V14       0.026557
#  V12       0.021051
#  V3        0.017918
#  V19       0.017036
#  V24       0.015884
#  V8        0.015256
#  V17       0.011861
#  V26       0.010401
#  V4        0.008589
#  Class     0.007692
#  V25       0.005236
#  V28       0.004422
#  V13       0.002728
#  V10       0.000190
#  Name: Amount, dtype: float64,
#  'correlation_fraud': Amount    1.000000
#  V8        0.266914
#  V19       0.244350
#  V24       0.215367
#  V5        0.192749
#  V4        0.187023
#  V2        0.180995
#  V14       0.177850
#  V15       0.168218
#  V13       0.165047
#  V26       0.154176
#  V11       0.149898
#  V28       0.130282
#  V17       0.123999
#  V7        0.120480
#  V9        0.119918
#  V18       0.118250
#  V23       0.116154
#  V12       0.093588
#  V27       0.081891
#  V10       0.076920
#  V1        0.075767
#  V16       0.062398
#  Time      0.054763
#  V20       0.049927
#  V6        0.048519
#  V21       0.048011
#  V22       0.014519
#  V3        0.013682
#  V25       0.011316
#  Class          NaN
#  Name: Amount, dtype: float64,
#  'correlation_nonfraud': Amount    1.000000
#  V2        0.436033
#  V5        0.278641
#  V6        0.161801
#  V20       0.129330
#  V16       0.099836
#  V9        0.092819
#  V1        0.088670
#  V21       0.085471
#  V7        0.082829
#  V15       0.074215
#  V11       0.056410
#  V22       0.048968
#  V27       0.048640
#  V18       0.036243
#  Time      0.029019
#  V23       0.027741
#  V12       0.025362
#  V14       0.024026
#  V3        0.020316
#  V8        0.019017
#  V19       0.017869
#  V24       0.016389
#  V17       0.013205
#  V4        0.010600
#  V26       0.010057
#  V25       0.005193
#  V28       0.003879
#  V13       0.003171
#  V10       0.002712
#  Class          NaN
#  Name: Amount, dtype: float64}
#         correlation  correlation_fraud  correlation_nonfraud
# Amount     1.000000           1.000000              1.000000
# Class      0.007692                NaN                   NaN
# Time       0.028724           0.054763              0.029019
# V1         0.087004           0.075767              0.088670
# V10        0.000190           0.076920              0.002712
# V11        0.057399           0.149898              0.056410
# V12        0.021051           0.093588              0.025362
# V13        0.002728           0.165047              0.003171
# V14        0.026557           0.177850              0.024026
# V15        0.073558           0.168218              0.074215
# V16        0.095224           0.062398              0.099836
# V17        0.011861           0.123999              0.013205
# V18        0.035539           0.118250              0.036243
# V19        0.017036           0.244350              0.017869
# V2         0.432917           0.180995              0.436033
# V20        0.128475           0.049927              0.129330
# V21        0.083550           0.048011              0.085471
# V22        0.048649           0.014519              0.048968
# V23        0.028194           0.116154              0.027741
# V24        0.015884           0.215367              0.016389
# V25        0.005236           0.011316              0.005193
# V26        0.010401           0.154176              0.010057
# V27        0.047584           0.081891              0.048640
# V28        0.004422           0.130282              0.003879
# V3         0.017918           0.013682              0.020316
# V4         0.008589           0.187023              0.010600
# V5         0.274332           0.192749              0.278641
# V6         0.161623           0.048519              0.161801
# V7         0.081907           0.120480              0.082829
# V8         0.015256           0.266914              0.019017
# V9         0.090543           0.119918              0.092819

# %%
# Fraud variables more correlated than nonfraud variables

f,(ax1,ax2,ax3, axcb) = plt.subplots(1,4, 
            gridspec_kw={'width_ratios':[1,1,1,0.08]}, figsize=(18,6))
ax1.get_shared_y_axes().join(ax2,ax3)
g1 = sns.heatmap(df.corr(),cmap="YlGnBu",cbar=False,ax=ax1)
g1.set_ylabel('')
g1.set_xlabel('All')
g2 = sns.heatmap(fraudulent_data.corr(),cmap="YlGnBu",cbar=False,ax=ax2)
g2.set_ylabel('')
g2.set_xlabel('Fraud')
g2.set_yticks([])
g3 = sns.heatmap(nonfraudulent_data.corr(),cmap="YlGnBu",ax=ax3, cbar_ax=axcb)
g3.set_ylabel('')
g3.set_xlabel('Non-Fraud')
g3.set_yticks([])
# Out:
# []

# %%
plt.figure(figsize=(18,12))
sns.scatterplot(x=df["Time"], y=df["Amount"], hue=df["Class"], size=df["Class"], sizes=(40, 8), marker="+")
# day night up down
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Amount'>

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(x=fraudulent_data["Time"], y=fraudulent_data["Amount"], sizes=(40, 8), marker="+")
sns.scatterplot(x=nonfraudulent_data["Time"], y=nonfraudulent_data["Amount"], sizes=(40, 8), marker="+")
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Amount'>

# %%
plt.boxplot ([df['V1'], df['V2'], df['V3'], df['V4'], df['V5'], df['V6'], df['V7'], df['V8'], df['V9'], df['V10']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff7914dd340>,
#   <matplotlib.lines.Line2D at 0x7ff7914dd6a0>,
#   <matplotlib.lines.Line2D at 0x7ff7914ebaf0>,
#   <matplotlib.lines.Line2D at 0x7ff7914ebe20>,
#   <matplotlib.lines.Line2D at 0x7ff7913331c0>,
#   <matplotlib.lines.Line2D at 0x7ff7913334f0>,
#   <matplotlib.lines.Line2D at 0x7ff791341850>,
#   <matplotlib.lines.Line2D at 0x7ff791341b80>,
#   <matplotlib.lines.Line2D at 0x7ff79134bee0>,
#   <matplotlib.lines.Line2D at 0x7ff791359250>,
#   <matplotlib.lines.Line2D at 0x7ff7913635b0>,
#   <matplotlib.lines.Line2D at 0x7ff7913638e0>,
#   <matplotlib.lines.Line2D at 0x7ff791cb8c40>,
#   <matplotlib.lines.Line2D at 0x7ff791cb8f70>,
#   <matplotlib.lines.Line2D at 0x7ff791cd1310>,
#   <matplotlib.lines.Line2D at 0x7ff791cd1640>,
#   <matplotlib.lines.Line2D at 0x7ff791cdd9a0>,
#   <matplotlib.lines.Line2D at 0x7ff791cddcd0>,
#   <matplotlib.lines.Line2D at 0x7ff792a7c070>,
#   <matplotlib.lines.Line2D at 0x7ff792a7c3a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff7914dda00>,
#   <matplotlib.lines.Line2D at 0x7ff7914ddd60>,
#   <matplotlib.lines.Line2D at 0x7ff791328190>,
#   <matplotlib.lines.Line2D at 0x7ff7913284c0>,
#   <matplotlib.lines.Line2D at 0x7ff791333820>,
#   <matplotlib.lines.Line2D at 0x7ff791333b50>,
#   <matplotlib.lines.Line2D at 0x7ff791341eb0>,
#   <matplotlib.lines.Line2D at 0x7ff79134b220>,
#   <matplotlib.lines.Line2D at 0x7ff791359580>,
#   <matplotlib.lines.Line2D at 0x7ff7913598b0>,
#   <matplotlib.lines.Line2D at 0x7ff791363c10>,
#   <matplotlib.lines.Line2D at 0x7ff791363f40>,
#   <matplotlib.lines.Line2D at 0x7ff791cc52e0>,
#   <matplotlib.lines.Line2D at 0x7ff791cc5610>,
#   <matplotlib.lines.Line2D at 0x7ff791cd1970>,
#   <matplotlib.lines.Line2D at 0x7ff791cd1ca0>,
#   <matplotlib.lines.Line2D at 0x7ff791cea040>,
#   <matplotlib.lines.Line2D at 0x7ff791cea370>,
#   <matplotlib.lines.Line2D at 0x7ff792a7c6d0>,
#   <matplotlib.lines.Line2D at 0x7ff792a7ca00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff7914cdfa0>,
#   <matplotlib.lines.Line2D at 0x7ff7914eb7c0>,
#   <matplotlib.lines.Line2D at 0x7ff791328e50>,
#   <matplotlib.lines.Line2D at 0x7ff791341520>,
#   <matplotlib.lines.Line2D at 0x7ff79134bbb0>,
#   <matplotlib.lines.Line2D at 0x7ff791363280>,
#   <matplotlib.lines.Line2D at 0x7ff791cb8910>,
#   <matplotlib.lines.Line2D at 0x7ff791cc5fa0>,
#   <matplotlib.lines.Line2D at 0x7ff791cdd670>,
#   <matplotlib.lines.Line2D at 0x7ff791cead00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff7914eb100>,
#   <matplotlib.lines.Line2D at 0x7ff7913287f0>,
#   <matplotlib.lines.Line2D at 0x7ff791333e80>,
#   <matplotlib.lines.Line2D at 0x7ff79134b550>,
#   <matplotlib.lines.Line2D at 0x7ff791359be0>,
#   <matplotlib.lines.Line2D at 0x7ff791cb82b0>,
#   <matplotlib.lines.Line2D at 0x7ff791cc5940>,
#   <matplotlib.lines.Line2D at 0x7ff791cd1fd0>,
#   <matplotlib.lines.Line2D at 0x7ff791cea6a0>,
#   <matplotlib.lines.Line2D at 0x7ff792a7cd30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff7914eb460>,
#   <matplotlib.lines.Line2D at 0x7ff791328b20>,
#   <matplotlib.lines.Line2D at 0x7ff7913411f0>,
#   <matplotlib.lines.Line2D at 0x7ff79134b880>,
#   <matplotlib.lines.Line2D at 0x7ff791359f10>,
#   <matplotlib.lines.Line2D at 0x7ff791cb85e0>,
#   <matplotlib.lines.Line2D at 0x7ff791cc5c70>,
#   <matplotlib.lines.Line2D at 0x7ff791cdd340>,
#   <matplotlib.lines.Line2D at 0x7ff791cea9d0>,
#   <matplotlib.lines.Line2D at 0x7ff792a8a0a0>],
#  'means': []}

# %%
plt.boxplot ([df['V11'], df['V12'], df['V13'], df['V14'], df['V15'], df['V16'], df['V17'], df['V18'], df['V19'], df['V20']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff790c66af0>,
#   <matplotlib.lines.Line2D at 0x7ff790e8b1f0>,
#   <matplotlib.lines.Line2D at 0x7ff790fe63d0>,
#   <matplotlib.lines.Line2D at 0x7ff790ff5400>,
#   <matplotlib.lines.Line2D at 0x7ff790d75400>,
#   <matplotlib.lines.Line2D at 0x7ff790d75f40>,
#   <matplotlib.lines.Line2D at 0x7ff791100130>,
#   <matplotlib.lines.Line2D at 0x7ff791100730>,
#   <matplotlib.lines.Line2D at 0x7ff790f80340>,
#   <matplotlib.lines.Line2D at 0x7ff790f80160>,
#   <matplotlib.lines.Line2D at 0x7ff790d66eb0>,
#   <matplotlib.lines.Line2D at 0x7ff790fcbfa0>,
#   <matplotlib.lines.Line2D at 0x7ff790f24e20>,
#   <matplotlib.lines.Line2D at 0x7ff790f24f40>,
#   <matplotlib.lines.Line2D at 0x7ff790fe3d60>,
#   <matplotlib.lines.Line2D at 0x7ff792a8ad00>,
#   <matplotlib.lines.Line2D at 0x7ff792aa18e0>,
#   <matplotlib.lines.Line2D at 0x7ff792aa1400>,
#   <matplotlib.lines.Line2D at 0x7ff7a0d26970>,
#   <matplotlib.lines.Line2D at 0x7ff7a0d26c70>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff790e8bc40>,
#   <matplotlib.lines.Line2D at 0x7ff790cc2550>,
#   <matplotlib.lines.Line2D at 0x7ff790ff5940>,
#   <matplotlib.lines.Line2D at 0x7ff790d822b0>,
#   <matplotlib.lines.Line2D at 0x7ff790d932e0>,
#   <matplotlib.lines.Line2D at 0x7ff790d93eb0>,
#   <matplotlib.lines.Line2D at 0x7ff791100ee0>,
#   <matplotlib.lines.Line2D at 0x7ff790fdf700>,
#   <matplotlib.lines.Line2D at 0x7ff790f80ee0>,
#   <matplotlib.lines.Line2D at 0x7ff790f80a60>,
#   <matplotlib.lines.Line2D at 0x7ff790fcb9d0>,
#   <matplotlib.lines.Line2D at 0x7ff79110eb20>,
#   <matplotlib.lines.Line2D at 0x7ff790fd7b80>,
#   <matplotlib.lines.Line2D at 0x7ff790fd7eb0>,
#   <matplotlib.lines.Line2D at 0x7ff79111d8e0>,
#   <matplotlib.lines.Line2D at 0x7ff7913de1f0>,
#   <matplotlib.lines.Line2D at 0x7ff792aa1d30>,
#   <matplotlib.lines.Line2D at 0x7ff790df2fa0>,
#   <matplotlib.lines.Line2D at 0x7ff7a0d260a0>,
#   <matplotlib.lines.Line2D at 0x7ff7a0db4d60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff790f974f0>,
#   <matplotlib.lines.Line2D at 0x7ff790fe6e50>,
#   <matplotlib.lines.Line2D at 0x7ff790db8910>,
#   <matplotlib.lines.Line2D at 0x7ff791100280>,
#   <matplotlib.lines.Line2D at 0x7ff790fdfd00>,
#   <matplotlib.lines.Line2D at 0x7ff790f85af0>,
#   <matplotlib.lines.Line2D at 0x7ff791122940>,
#   <matplotlib.lines.Line2D at 0x7ff790fe3160>,
#   <matplotlib.lines.Line2D at 0x7ff792aa1f70>,
#   <matplotlib.lines.Line2D at 0x7ff7a0d263d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff790cc2b20>,
#   <matplotlib.lines.Line2D at 0x7ff790d82d30>,
#   <matplotlib.lines.Line2D at 0x7ff790d93910>,
#   <matplotlib.lines.Line2D at 0x7ff790fdf100>,
#   <matplotlib.lines.Line2D at 0x7ff791121970>,
#   <matplotlib.lines.Line2D at 0x7ff79110e4f0>,
#   <matplotlib.lines.Line2D at 0x7ff7914eb2b0>,
#   <matplotlib.lines.Line2D at 0x7ff791109d30>,
#   <matplotlib.lines.Line2D at 0x7ff790d1eac0>,
#   <matplotlib.lines.Line2D at 0x7ff7a0db4340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff790fe6280>,
#   <matplotlib.lines.Line2D at 0x7ff790d82a60>,
#   <matplotlib.lines.Line2D at 0x7ff790d9d850>,
#   <matplotlib.lines.Line2D at 0x7ff790fdf760>,
#   <matplotlib.lines.Line2D at 0x7ff790f853a0>,
#   <matplotlib.lines.Line2D at 0x7ff79110ebe0>,
#   <matplotlib.lines.Line2D at 0x7ff790fe38b0>,
#   <matplotlib.lines.Line2D at 0x7ff792aac6d0>,
#   <matplotlib.lines.Line2D at 0x7ff7a0d26400>,
#   <matplotlib.lines.Line2D at 0x7ff7a0db42e0>],
#  'means': []}

# %%
plt.boxplot ([df['V21'], df['V22'], df['V23'], df['V24'], df['V25'], df['V26'], df['V27'], df['V28']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff79323a370>,
#   <matplotlib.lines.Line2D at 0x7ff79323a6d0>,
#   <matplotlib.lines.Line2D at 0x7ff793247b50>,
#   <matplotlib.lines.Line2D at 0x7ff793247eb0>,
#   <matplotlib.lines.Line2D at 0x7ff793260370>,
#   <matplotlib.lines.Line2D at 0x7ff7932606d0>,
#   <matplotlib.lines.Line2D at 0x7ff79326cb50>,
#   <matplotlib.lines.Line2D at 0x7ff79326ceb0>,
#   <matplotlib.lines.Line2D at 0x7ff793578370>,
#   <matplotlib.lines.Line2D at 0x7ff7935786d0>,
#   <matplotlib.lines.Line2D at 0x7ff793586b50>,
#   <matplotlib.lines.Line2D at 0x7ff793586eb0>,
#   <matplotlib.lines.Line2D at 0x7ff79359b3a0>,
#   <matplotlib.lines.Line2D at 0x7ff79359b700>,
#   <matplotlib.lines.Line2D at 0x7ff7936a4b80>,
#   <matplotlib.lines.Line2D at 0x7ff7936a4ee0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff79323aa30>,
#   <matplotlib.lines.Line2D at 0x7ff79323ad90>,
#   <matplotlib.lines.Line2D at 0x7ff793252250>,
#   <matplotlib.lines.Line2D at 0x7ff7932525b0>,
#   <matplotlib.lines.Line2D at 0x7ff793260a30>,
#   <matplotlib.lines.Line2D at 0x7ff793260d90>,
#   <matplotlib.lines.Line2D at 0x7ff79356c250>,
#   <matplotlib.lines.Line2D at 0x7ff79356c5b0>,
#   <matplotlib.lines.Line2D at 0x7ff793578a30>,
#   <matplotlib.lines.Line2D at 0x7ff793578d90>,
#   <matplotlib.lines.Line2D at 0x7ff793590280>,
#   <matplotlib.lines.Line2D at 0x7ff7935905e0>,
#   <matplotlib.lines.Line2D at 0x7ff79359ba60>,
#   <matplotlib.lines.Line2D at 0x7ff79359bdc0>,
#   <matplotlib.lines.Line2D at 0x7ff7936af280>,
#   <matplotlib.lines.Line2D at 0x7ff7936af5e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff79311bfd0>,
#   <matplotlib.lines.Line2D at 0x7ff7932477f0>,
#   <matplotlib.lines.Line2D at 0x7ff793252fd0>,
#   <matplotlib.lines.Line2D at 0x7ff79326c7f0>,
#   <matplotlib.lines.Line2D at 0x7ff79356cfd0>,
#   <matplotlib.lines.Line2D at 0x7ff7935867f0>,
#   <matplotlib.lines.Line2D at 0x7ff79359b040>,
#   <matplotlib.lines.Line2D at 0x7ff7936a4820>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff793247130>,
#   <matplotlib.lines.Line2D at 0x7ff793252910>,
#   <matplotlib.lines.Line2D at 0x7ff79326c130>,
#   <matplotlib.lines.Line2D at 0x7ff79356c910>,
#   <matplotlib.lines.Line2D at 0x7ff793586130>,
#   <matplotlib.lines.Line2D at 0x7ff793590940>,
#   <matplotlib.lines.Line2D at 0x7ff7936a4160>,
#   <matplotlib.lines.Line2D at 0x7ff7936af940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff793247490>,
#   <matplotlib.lines.Line2D at 0x7ff793252c70>,
#   <matplotlib.lines.Line2D at 0x7ff79326c490>,
#   <matplotlib.lines.Line2D at 0x7ff79356cc70>,
#   <matplotlib.lines.Line2D at 0x7ff793586490>,
#   <matplotlib.lines.Line2D at 0x7ff793590ca0>,
#   <matplotlib.lines.Line2D at 0x7ff7936a44c0>,
#   <matplotlib.lines.Line2D at 0x7ff7936afca0>],
#  'means': []}

# %% [markdown]
# # Parametrización de TPOT
#
# TPOT cuenta con parámetros propios de los algoritmos genéticos. Estos resultan clave para la determinación del tiempo necesario para encontrar el pipeline que mejor ajuste al problema, como asi también la convergencia a una solución global.

# %% [markdown]
# ## Parámetros de los algoritmos genéticos.
#
# * **generations**: Es el número de iteraciones que repite el proceso de optimización del pipeline. El valor por defecto es de 100.
#
#
#
# * **population_size:** int, optional (default=100)
# Número de 'individuos' (soluciones) que se retienen de la poblacion de cada generación en la que corre el proceso.
# Generally, TPOT will work better when you give it more individuals with which to optimize the pipeline.
#
# * **offspring_size:** int, optional (default=None)
# Número de 'offspring' (crías) que se producen en cada generación. Por defecto, es igual al numero de *population_size*.
#
# * **mutation_rate:** float, optional (default=0.9)
# Indica a que proporción de pipelines se le aplica modificaciones aleatorias en cada generación.
#
# mutation_rate + crossover_rate no puede exceder 1.0.
#
#
# * **crossover_rate:** float, optional (default=0.1)
# Crossover rate for the genetic programming algorithm in the range [0.0, 1.0]. Indica qué proporción de pipelines se 'crían' en cada generación.
#
# mutation_rate + crossover_rate cannot exceed 1.0.
#
# Se recomienda dejar los valores por defecto si no se conocen los algoritmos genéticos.
#
# La cantidad de pipelines va a estar determinada por: population_size + (generations * offspring_size).
#
# En este caso establecemos 5 generaciones y dejamos el resto de las valiables en sus valores por defecto, por lo que tpot evaluará 600 pipelines

# %% [markdown]
# ## Algunos otros parámetros de TPOT
#
# * **scoring** : métrica utilizada para evaluar el ajuste del pipeline. En nuetro caso utilizamos 'f1' ya que trabajamos con un dataset altamente desbalanceado y de clasificación binaria.
#
# * **cv**: Esquema de cross-validation para evaluar los pipelines. Dejamos el valor por defecto (5 carpetas).
#
# * **subsamle** : Fracción de datos que se entrena en cada pipeline. Dejamos el valor por defecto (1.0).
#
# * **max_time_mins**: Indica en cuántos minutos TPOT debe optimizar el pipeline. No establecemos ningún valor, permitiendo que TPOT corra el tiempo necesario.
#
# * **max_eval_time_mins**: Indica el tiempo que tiene TPOT para evaluar un pipeline. Previene grandes pérdidas de tiempo, con la desventaja de dejar de lado pipelines mas complejos. Dejamos el valor por defecto de 5 minutos.

# %%
#Separamos la variable objetivo del dataset
df = df.dropna()
target = df.Class
df = df.drop(['Class'], axis=1)
display(df.isna().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
#Generamos los set de entrenamiento y test.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df, target, stratify=target)

# %%
#Generamos el pipeline

tpot = TPOTClassifier(generations=5, population_size=100,
                          offspring_size=None, mutation_rate=0.9,
                          crossover_rate=0.1,
                          scoring='f1', cv=5,
                          subsample=1.0, n_jobs=1,
                          max_time_mins=None, max_eval_time_mins=5,
                          random_state=43, config_dict=None,
                          warm_start=False,
                          memory=None,
                          periodic_checkpoint_folder=None,
                          early_stop=None,
                          verbosity=3,
                          disable_update_check=False)

# %%
#Generamos la instancia de entrenamiento
start = time.time()

tpot.fit(x_train, y_train)

end = time.time()
print(f"Runtime of the program is {(end - start/60)} minutes")
# Out:
# 32 operators have been imported by TPOT.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=600.0, style=ProgressStyle(de…
# Skipped pipeline #14 due to time out. Continuing to the next pipeline.
# Skipped pipeline #17 due to time out. Continuing to the next pipeline.
# Skipped pipeline #28 due to time out. Continuing to the next pipeline.
# Skipped pipeline #30 due to time out. Continuing to the next pipeline.
# Skipped pipeline #34 due to time out. Continuing to the next pipeline.
# Skipped pipeline #36 due to time out. Continuing to the next pipeline.
# Skipped pipeline #43 due to time out. Continuing to the next pipeline.
# Skipped pipeline #50 due to time out. Continuing to the next pipeline.
# Skipped pipeline #62 due to time out. Continuing to the next pipeline.
# Skipped pipeline #67 due to time out. Continuing to the next pipeline.
# Skipped pipeline #70 due to time out. Continuing to the next pipeline.
# Skipped pipeline #90 due to time out. Continuing to the next pipeline.
# Skipped pipeline #92 due to time out. Continuing to the next pipeline.
# Skipped pipeline #96 due to time out. Continuing to the next pipeline.
# Skipped pipeline #104 due to time out. Continuing to the next pipeline.
# Skipped pipeline #109 due to time out. Continuing to the next pipeline.
# Skipped pipeline #111 due to time out. Continuing to the next pipeline.
# Skipped pipeline #113 due to time out. Continuing to the next pipeline.
# Skipped pipeline #115 due to time out. Continuing to the next pipeline.
# Skipped pipeline #119 due to time out. Continuing to the next pipeline.
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=1 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=1 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required by RobustScaler..
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# Skipped pipeline #130 due to time out. Continuing to the next pipeline.
# Skipped pipeline #132 due to time out. Continuing to the next pipeline.
# Skipped pipeline #144 due to time out. Continuing to the next pipeline.
# Skipped pipeline #147 due to time out. Continuing to the next pipeline.
# Skipped pipeline #149 due to time out. Continuing to the next pipeline.
# Skipped pipeline #155 due to time out. Continuing to the next pipeline.
# Skipped pipeline #158 due to time out. Continuing to the next pipeline.
# Skipped pipeline #167 due to time out. Continuing to the next pipeline.
# Skipped pipeline #169 due to time out. Continuing to the next pipeline.
# Skipped pipeline #175 due to time out. Continuing to the next pipeline.
# Skipped pipeline #186 due to time out. Continuing to the next pipeline.
# Skipped pipeline #188 due to time out. Continuing to the next pipeline.
# Skipped pipeline #193 due to time out. Continuing to the next pipeline.
# Skipped pipeline #195 due to time out. Continuing to the next pipeline.
# Skipped pipeline #198 due to time out. Continuing to the next pipeline.
# Skipped pipeline #200 due to time out. Continuing to the next pipeline.
# Skipped pipeline #203 due to time out. Continuing to the next pipeline.
# Skipped pipeline #205 due to time out. Continuing to the next pipeline.
# Skipped pipeline #208 due to time out. Continuing to the next pipeline.
# Skipped pipeline #215 due to time out. Continuing to the next pipeline.
# Skipped pipeline #221 due to time out. Continuing to the next pipeline.
# Skipped pipeline #228 due to time out. Continuing to the next pipeline.
# Skipped pipeline #241 due to time out. Continuing to the next pipeline.
#
# Generation 1 - Current Pareto front scores:
#
# -1	0.8377075540738332	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 cosine was provided as affinity. Ward can only work with euclidean distances..
# _pre_test decorator: _random_mutation_operator: num_test=0 cosine was provided as affinity. Ward can only work with euclidean distances..
# _pre_test decorator: _random_mutation_operator: num_test=1 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=2 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _mate_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 manhattan was provided as affinity. Ward can only work with euclidean distances..
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=1 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=1 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #249 due to time out. Continuing to the next pipeline.
# Skipped pipeline #255 due to time out. Continuing to the next pipeline.
# Skipped pipeline #262 due to time out. Continuing to the next pipeline.
# Skipped pipeline #265 due to time out. Continuing to the next pipeline.
# Skipped pipeline #267 due to time out. Continuing to the next pipeline.
# Skipped pipeline #280 due to time out. Continuing to the next pipeline.
# Skipped pipeline #292 due to time out. Continuing to the next pipeline.
# Skipped pipeline #310 due to time out. Continuing to the next pipeline.
# Skipped pipeline #314 due to time out. Continuing to the next pipeline.
# Skipped pipeline #321 due to time out. Continuing to the next pipeline.
# Skipped pipeline #347 due to time out. Continuing to the next pipeline.
#
# Generation 2 - Current Pareto front scores:
#
# -1	0.8407844771507562	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.6500000000000001, ExtraTreesClassifier__min_samples_leaf=1, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
#
# -2	0.8490489692524001	ExtraTreesClassifier(FastICA(input_matrix, FastICA__tol=0.55), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.4, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=1 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=1 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _mate_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l2' and loss='hinge' are not supported when dual=False, Parameters: penalty='l2', loss='hinge', dual=False.
# _pre_test decorator: _mate_operator: num_test=1 Unsupported set of arguments: The combination of penalty='l2' and loss='hinge' are not supported when dual=False, Parameters: penalty='l2', loss='hinge', dual=False.
# _pre_test decorator: _mate_operator: num_test=2 Unsupported set of arguments: The combination of penalty='l2' and loss='hinge' are not supported when dual=False, Parameters: penalty='l2', loss='hinge', dual=False.
# _pre_test decorator: _mate_operator: num_test=3 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True.
# _pre_test decorator: _mate_operator: num_test=4 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #368 due to time out. Continuing to the next pipeline.
# Skipped pipeline #373 due to time out. Continuing to the next pipeline.
# Skipped pipeline #393 due to time out. Continuing to the next pipeline.
# Skipped pipeline #410 due to time out. Continuing to the next pipeline.
# Skipped pipeline #422 due to time out. Continuing to the next pipeline.
# Skipped pipeline #424 due to time out. Continuing to the next pipeline.
# Skipped pipeline #428 due to time out. Continuing to the next pipeline.
# Skipped pipeline #434 due to time out. Continuing to the next pipeline.
# Skipped pipeline #449 due to time out. Continuing to the next pipeline.
# Skipped pipeline #454 due to time out. Continuing to the next pipeline.
# Skipped pipeline #457 due to time out. Continuing to the next pipeline.
# Skipped pipeline #465 due to time out. Continuing to the next pipeline.
#
# Generation 3 - Current Pareto front scores:
#
# -1	0.8407844771507562	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.6500000000000001, ExtraTreesClassifier__min_samples_leaf=1, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
#
# -2	0.8490489692524001	ExtraTreesClassifier(FastICA(input_matrix, FastICA__tol=0.55), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.4, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 manhattan was provided as affinity. Ward can only work with euclidean distances..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 [21:32:55] /Users/runner/miniforge3/conda-bld/xgboost_1607604592557/work/src/learner.cc:567: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x000000011c72d23e dmlc::LogMessageFatal::~LogMessageFatal() + 110
#   [bt] (1) 2   libxgboost.dylib                    0x000000011c7e8173 xgboost::LearnerConfiguration::ConfigureNumFeatures() + 963
#   [bt] (2) 3   libxgboost.dylib                    0x000000011c7ddd51 xgboost::LearnerConfiguration::Configure() + 1041
#   [bt] (3) 4   libxgboost.dylib                    0x000000011c7de2e7 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 119
#   [bt] (4) 5   libxgboost.dylib                    0x000000011c731e5c XGBoosterUpdateOneIter + 156
#   [bt] (5) 6   libffi.6.dylib                      0x0000000101afd934 ffi_call_unix64 + 76
#   [bt] (6) 7   ???                                 0x00007ffeeed36f40 0x0 + 140732905254720
#
# .
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# Skipped pipeline #475 due to time out. Continuing to the next pipeline.
# Skipped pipeline #482 due to time out. Continuing to the next pipeline.
# Skipped pipeline #498 due to time out. Continuing to the next pipeline.
# Skipped pipeline #502 due to time out. Continuing to the next pipeline.
# Skipped pipeline #512 due to time out. Continuing to the next pipeline.
# Skipped pipeline #535 due to time out. Continuing to the next pipeline.
# Skipped pipeline #542 due to time out. Continuing to the next pipeline.
# Skipped pipeline #548 due to time out. Continuing to the next pipeline.
# Skipped pipeline #556 due to time out. Continuing to the next pipeline.
# Skipped pipeline #560 due to time out. Continuing to the next pipeline.
# Skipped pipeline #566 due to time out. Continuing to the next pipeline.
# Skipped pipeline #568 due to time out. Continuing to the next pipeline.
# Skipped pipeline #576 due to time out. Continuing to the next pipeline.
#
# Generation 4 - Current Pareto front scores:
#
# -1	0.843771007160187	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.6000000000000001, ExtraTreesClassifier__min_samples_leaf=1, ExtraTreesClassifier__min_samples_split=7, ExtraTreesClassifier__n_estimators=100)
#
# -2	0.8509160212561809	ExtraTreesClassifier(FastICA(input_matrix, FastICA__tol=0.35000000000000003), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.5, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=1 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# Skipped pipeline #586 due to time out. Continuing to the next pipeline.
# Skipped pipeline #602 due to time out. Continuing to the next pipeline.
# Skipped pipeline #607 due to time out. Continuing to the next pipeline.
# Skipped pipeline #610 due to time out. Continuing to the next pipeline.
# Skipped pipeline #616 due to time out. Continuing to the next pipeline.
# Skipped pipeline #618 due to time out. Continuing to the next pipeline.
# Skipped pipeline #629 due to time out. Continuing to the next pipeline.
# Skipped pipeline #632 due to time out. Continuing to the next pipeline.
# Skipped pipeline #643 due to time out. Continuing to the next pipeline.
# Skipped pipeline #649 due to time out. Continuing to the next pipeline.
# Skipped pipeline #655 due to time out. Continuing to the next pipeline.
# Skipped pipeline #657 due to time out. Continuing to the next pipeline.
# Skipped pipeline #662 due to time out. Continuing to the next pipeline.
# Skipped pipeline #670 due to time out. Continuing to the next pipeline.
# Skipped pipeline #675 due to time out. Continuing to the next pipeline.
# Skipped pipeline #685 due to time out. Continuing to the next pipeline.
# Skipped pipeline #694 due to time out. Continuing to the next pipeline.
#
# Generation 5 - Current Pareto front scores:
#
# -1	0.843771007160187	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.6000000000000001, ExtraTreesClassifier__min_samples_leaf=1, ExtraTreesClassifier__min_samples_split=7, ExtraTreesClassifier__n_estimators=100)
#
# -2	0.8509160212561809	ExtraTreesClassifier(FastICA(input_matrix, FastICA__tol=0.35000000000000003), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.5, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
# Runtime of the program is 1583123873.4570413 minutes

# %%
#Generamos la instancia de predicciones
pred=tpot.predict(df)

# %%
#Evaluamos el desempeño
tpot.score(x_test, y_test)
# Out:
# 0.9189189189189189

# %%
from sklearn.metrics import confusion_matrix,precision_recall_curve,auc,roc_auc_score,roc_curve,recall_score,classification_report, plot_precision_recall_curve, average_precision_score
print(confusion_matrix(target, pred))
# Out:
# [[282513      4]
#  [    68    397]]

# %%
print(classification_report(target, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    282517
#            1       0.99      0.85      0.92       465
#
#     accuracy                           1.00    282982
#    macro avg       0.99      0.93      0.96    282982
# weighted avg       1.00      1.00      1.00    282982

# %%
Check it out
#Precision Recall curve
average_precision = average_precision_score(y_test, y_score)
disp = plot_precision_recall_curve(tpot, x_test, y_test)
disp.ax_.set_title('2-class Precision-Recall curve: '
                   'AP={0:0.2f}'.format(average_precision))

# %% [markdown]
# # Second Tpot Model
#
# We maintain the status quo (mutation_rate+crossover_rate=1) to check whether the proportion of pipelines creations or the pipelines created by generation gets better results. Increasing the second at the cost of the first might not increase the efficacy since freedom of pipeline creation is cut from the beggining

# %%
#Generamos el pipeline

tpot_1 = TPOTClassifier(generations=5, population_size=100,
                          offspring_size=None, mutation_rate=0.5,
                          crossover_rate=0.5,
                          scoring='f1', cv=5,
                          subsample=1.0, n_jobs=1,
                          max_time_mins=None, max_eval_time_mins=5,
                          random_state=43, config_dict=None,
                          warm_start=False,
                          memory=None,
                          periodic_checkpoint_folder=None,
                          early_stop=None,
                          verbosity=3,
                          disable_update_check=False)

#Generamos la instancia de entrenamiento
start = time.time()

tpot_1.fit(x_train, y_train)

end = time.time()
print(f"Runtime of the program is {(end - start/60)} minutes")
# Out:
# 32 operators have been imported by TPOT.
# Version 0.11.6.post3 of tpot is outdated. Version 0.11.7 was released 3 hours ago.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=600.0, style=ProgressStyle(de…
# Skipped pipeline #14 due to time out. Continuing to the next pipeline.
# Skipped pipeline #17 due to time out. Continuing to the next pipeline.
# Skipped pipeline #28 due to time out. Continuing to the next pipeline.
# Skipped pipeline #30 due to time out. Continuing to the next pipeline.
# Skipped pipeline #34 due to time out. Continuing to the next pipeline.
# Skipped pipeline #36 due to time out. Continuing to the next pipeline.
# Skipped pipeline #39 due to time out. Continuing to the next pipeline.
# Skipped pipeline #44 due to time out. Continuing to the next pipeline.
# Skipped pipeline #51 due to time out. Continuing to the next pipeline.
# Skipped pipeline #63 due to time out. Continuing to the next pipeline.
# Skipped pipeline #68 due to time out. Continuing to the next pipeline.
# Skipped pipeline #71 due to time out. Continuing to the next pipeline.
# Skipped pipeline #91 due to time out. Continuing to the next pipeline.
# Skipped pipeline #93 due to time out. Continuing to the next pipeline.
# Skipped pipeline #97 due to time out. Continuing to the next pipeline.
# Skipped pipeline #105 due to time out. Continuing to the next pipeline.
# Skipped pipeline #110 due to time out. Continuing to the next pipeline.
# Skipped pipeline #112 due to time out. Continuing to the next pipeline.
# Skipped pipeline #114 due to time out. Continuing to the next pipeline.
# Skipped pipeline #116 due to time out. Continuing to the next pipeline.
# Skipped pipeline #120 due to time out. Continuing to the next pipeline.
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 64.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=1 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 96.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=1 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _mate_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #134 due to time out. Continuing to the next pipeline.
# Skipped pipeline #137 due to time out. Continuing to the next pipeline.
# Skipped pipeline #140 due to time out. Continuing to the next pipeline.
# Skipped pipeline #147 due to time out. Continuing to the next pipeline.
# Skipped pipeline #153 due to time out. Continuing to the next pipeline.
# Skipped pipeline #174 due to time out. Continuing to the next pipeline.
# Skipped pipeline #176 due to time out. Continuing to the next pipeline.
# Skipped pipeline #180 due to time out. Continuing to the next pipeline.
# Skipped pipeline #185 due to time out. Continuing to the next pipeline.
# Skipped pipeline #191 due to time out. Continuing to the next pipeline.
# Skipped pipeline #195 due to time out. Continuing to the next pipeline.
# Skipped pipeline #200 due to time out. Continuing to the next pipeline.
# Skipped pipeline #204 due to time out. Continuing to the next pipeline.
# Skipped pipeline #206 due to time out. Continuing to the next pipeline.
# Skipped pipeline #208 due to time out. Continuing to the next pipeline.
# Skipped pipeline #210 due to time out. Continuing to the next pipeline.
# Skipped pipeline #219 due to time out. Continuing to the next pipeline.
# Skipped pipeline #222 due to time out. Continuing to the next pipeline.
# Skipped pipeline #225 due to time out. Continuing to the next pipeline.
# Skipped pipeline #228 due to time out. Continuing to the next pipeline.
# Skipped pipeline #231 due to time out. Continuing to the next pipeline.
# Skipped pipeline #238 due to time out. Continuing to the next pipeline.
# Skipped pipeline #240 due to time out. Continuing to the next pipeline.
#
# Generation 1 - Current Pareto front scores:
#
# -1	0.8377075540738332	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
#
# -2	0.8414949305147779	ExtraTreesClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.15000000000000002, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.45), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 56.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _mate_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# _pre_test decorator: _mate_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# _pre_test decorator: _mate_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #263 due to time out. Continuing to the next pipeline.
# Skipped pipeline #274 due to time out. Continuing to the next pipeline.
# Skipped pipeline #298 due to time out. Continuing to the next pipeline.
# Skipped pipeline #301 due to time out. Continuing to the next pipeline.
# Skipped pipeline #317 due to time out. Continuing to the next pipeline.
# Skipped pipeline #328 due to time out. Continuing to the next pipeline.
# Skipped pipeline #332 due to time out. Continuing to the next pipeline.
# Skipped pipeline #338 due to time out. Continuing to the next pipeline.
# Skipped pipeline #346 due to time out. Continuing to the next pipeline.
#
# Generation 2 - Current Pareto front scores:
#
# -1	0.8377075540738332	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
#
# -2	0.8414949305147779	ExtraTreesClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.15000000000000002, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.45), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 76.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #358 due to time out. Continuing to the next pipeline.
# Skipped pipeline #364 due to time out. Continuing to the next pipeline.
# Skipped pipeline #387 due to time out. Continuing to the next pipeline.
# Skipped pipeline #392 due to time out. Continuing to the next pipeline.
# Skipped pipeline #395 due to time out. Continuing to the next pipeline.
# Skipped pipeline #412 due to time out. Continuing to the next pipeline.
# Skipped pipeline #428 due to time out. Continuing to the next pipeline.
# Skipped pipeline #431 due to time out. Continuing to the next pipeline.
# Skipped pipeline #440 due to time out. Continuing to the next pipeline.
# Skipped pipeline #461 due to time out. Continuing to the next pipeline.
#
# Generation 3 - Current Pareto front scores:
#
# -1	0.8377075540738332	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
#
# -2	0.8414949305147779	ExtraTreesClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.15000000000000002, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.45), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 79.
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 70.
# _pre_test decorator: _random_mutation_operator: num_test=0 [12:09:03] /Users/runner/miniforge3/conda-bld/xgboost_1607604592557/work/src/learner.cc:567: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x000000011c72d23e dmlc::LogMessageFatal::~LogMessageFatal() + 110
#   [bt] (1) 2   libxgboost.dylib                    0x000000011c7e8173 xgboost::LearnerConfiguration::ConfigureNumFeatures() + 963
#   [bt] (2) 3   libxgboost.dylib                    0x000000011c7ddd51 xgboost::LearnerConfiguration::Configure() + 1041
#   [bt] (3) 4   libxgboost.dylib                    0x000000011c7de2e7 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 119
#   [bt] (4) 5   libxgboost.dylib                    0x000000011c731e5c XGBoosterUpdateOneIter + 156
#   [bt] (5) 6   libffi.6.dylib                      0x0000000101afd934 ffi_call_unix64 + 76
#   [bt] (6) 7   ???                                 0x00007ffeeed36f40 0x0 + 140732905254720
#
# .
# _pre_test decorator: _random_mutation_operator: num_test=0 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=1 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=1 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #487 due to time out. Continuing to the next pipeline.
# Skipped pipeline #516 due to time out. Continuing to the next pipeline.
# Skipped pipeline #524 due to time out. Continuing to the next pipeline.
# Skipped pipeline #538 due to time out. Continuing to the next pipeline.
# Skipped pipeline #553 due to time out. Continuing to the next pipeline.
# Skipped pipeline #555 due to time out. Continuing to the next pipeline.
# Skipped pipeline #559 due to time out. Continuing to the next pipeline.
#
# Generation 4 - Current Pareto front scores:
#
# -1	0.8463068135969707	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.6500000000000001, ExtraTreesClassifier__min_samples_leaf=1, ExtraTreesClassifier__min_samples_split=3, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 73.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #581 due to time out. Continuing to the next pipeline.
# Skipped pipeline #597 due to time out. Continuing to the next pipeline.
# Skipped pipeline #604 due to time out. Continuing to the next pipeline.
# Skipped pipeline #610 due to time out. Continuing to the next pipeline.
# Skipped pipeline #623 due to time out. Continuing to the next pipeline.
# Skipped pipeline #626 due to time out. Continuing to the next pipeline.
# Skipped pipeline #633 due to time out. Continuing to the next pipeline.
# Skipped pipeline #648 due to time out. Continuing to the next pipeline.
# Skipped pipeline #663 due to time out. Continuing to the next pipeline.
# Skipped pipeline #675 due to time out. Continuing to the next pipeline.
#
# Generation 5 - Current Pareto front scores:
#
# -1	0.8477189881667258	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8500000000000001, ExtraTreesClassifier__min_samples_leaf=1, ExtraTreesClassifier__min_samples_split=3, ExtraTreesClassifier__n_estimators=100)
#
# -3	0.8492704915446335	XGBClassifier(MinMaxScaler(MinMaxScaler(input_matrix)), XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=2, XGBClassifier__min_child_weight=18, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.9000000000000001, XGBClassifier__verbosity=0)
# Runtime of the program is 1583239415.2386885 minutes

# %%
#Generamos la instancia de predicciones
pred=tpot_1.predict(df)

#Evaluamos el desempeño
tpot_1.score(x_test, y_test)
print(tpot_1.score(x_test, y_test))
print(confusion_matrix(target, pred))

print(classification_report(target, pred))
# Out:
# 0.8847926267281105
# [[282508      9]
#  [    80    385]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    282517
#            1       0.98      0.83      0.90       465
#
#     accuracy                           1.00    282982
#    macro avg       0.99      0.91      0.95    282982
# weighted avg       1.00      1.00      1.00    282982

# %% [markdown]
# # Third Model
# Leaving mutation rate as a float might increase freedom of optimal pipelines and, therefore, increase efficacy of the results. Somehow it does not run (even if cv is set to 0.1)

# %%
#Generamos el pipeline

tpot_2 = TPOTClassifier(generations=5, population_size=100,
                          offspring_size=None, mutation_rate=float,
                          crossover_rate=float,
                          scoring='f1', cv=5,
                          subsample=1.0, n_jobs=1,
                          max_time_mins=None, max_eval_time_mins=5,
                          random_state=43, config_dict=None,
                          warm_start=False,
                          memory=None,
                          periodic_checkpoint_folder=None,
                          early_stop=None,
                          verbosity=3,
                          disable_update_check=False)

#Generamos la instancia de entrenamiento
start = time.time()

tpot_2.fit(x_train, y_train)

end = time.time()
print(f"Runtime of the program is {(end - start/60)} minutes")
# Out:
# 32 operators have been imported by TPOT.
# Version 0.11.6.post3 of tpot is outdated. Version 0.11.7 was released 1 day ago.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-745aa4576fb0> in <module>
#      18 start = time.time()
#      19
# ---> 20 tpot_2.fit(x_train, y_train)
#      21
#      22 end = time.time()
#
# ~/miniconda3/lib/python3.8/site-packages/tpot/base.py in fit(self, features, target, sample_weight, groups)
#     656
#     657         """
# --> 658         self._fit_init()
#     659         features, target = self._check_dataset(features, target, sample_weight)
#     660
#
# ~/miniconda3/lib/python3.8/site-packages/tpot/base.py in _fit_init(self)
#     582             update_check('tpot', __version__)
#     583
# --> 584         if self.mutation_rate + self.crossover_rate > 1:
#     585             raise ValueError(
#     586                 'The sum of the crossover and mutation probabilities must be <= 1.0.'
#
# TypeError: unsupported operand type(s) for +: 'type' and 'type'

# %% [markdown]
# # Fourth Model
# Subsample float could be optimal to automatic detection of sample. : Fraction of training samples that are used during the TPOT optimization process. Setting a 0.7 to 0.3 could be an option

# %%
#Generamos el pipeline

tpot_3 = TPOTClassifier(generations=5, population_size=100,
                          offspring_size=None, mutation_rate=0.9,
                          crossover_rate=0.1,
                          scoring='f1', cv=5,
                          subsample=0.7, n_jobs=1,
                          max_time_mins=None, max_eval_time_mins=5,
                          random_state=43, config_dict=None,
                          warm_start=False,
                          memory=None,
                          periodic_checkpoint_folder=None,
                          early_stop=None,
                          verbosity=3,
                          disable_update_check=False)

#Generamos la instancia de entrenamiento
start = time.time()

tpot_3.fit(x_train, y_train)

end = time.time()
print(f"Runtime of the program is {(end - start/60)} minutes")
# Out:
# 32 operators have been imported by TPOT.
# Version 0.11.6.post3 of tpot is outdated. Version 0.11.7 was released 1 day ago.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=600.0, style=ProgressStyle(de…
# Skipped pipeline #14 due to time out. Continuing to the next pipeline.
# Skipped pipeline #17 due to time out. Continuing to the next pipeline.
# Skipped pipeline #28 due to time out. Continuing to the next pipeline.
# Skipped pipeline #30 due to time out. Continuing to the next pipeline.
# Skipped pipeline #34 due to time out. Continuing to the next pipeline.
# Skipped pipeline #42 due to time out. Continuing to the next pipeline.
# Skipped pipeline #49 due to time out. Continuing to the next pipeline.
# Skipped pipeline #67 due to time out. Continuing to the next pipeline.
# Skipped pipeline #87 due to time out. Continuing to the next pipeline.
# Skipped pipeline #92 due to time out. Continuing to the next pipeline.
# Skipped pipeline #100 due to time out. Continuing to the next pipeline.
# Skipped pipeline #106 due to time out. Continuing to the next pipeline.
# Skipped pipeline #108 due to time out. Continuing to the next pipeline.
# Skipped pipeline #110 due to time out. Continuing to the next pipeline.
# Skipped pipeline #114 due to time out. Continuing to the next pipeline.
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=1 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=1 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required by RobustScaler..
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# Skipped pipeline #125 due to time out. Continuing to the next pipeline.
# Skipped pipeline #127 due to time out. Continuing to the next pipeline.
# Skipped pipeline #139 due to time out. Continuing to the next pipeline.
# Skipped pipeline #142 due to time out. Continuing to the next pipeline.
# Skipped pipeline #144 due to time out. Continuing to the next pipeline.
# Skipped pipeline #152 due to time out. Continuing to the next pipeline.
# Skipped pipeline #161 due to time out. Continuing to the next pipeline.
# Skipped pipeline #163 due to time out. Continuing to the next pipeline.
# Skipped pipeline #169 due to time out. Continuing to the next pipeline.
# Skipped pipeline #180 due to time out. Continuing to the next pipeline.
# Skipped pipeline #186 due to time out. Continuing to the next pipeline.
# Skipped pipeline #188 due to time out. Continuing to the next pipeline.
# Skipped pipeline #191 due to time out. Continuing to the next pipeline.
# Skipped pipeline #195 due to time out. Continuing to the next pipeline.
# Skipped pipeline #197 due to time out. Continuing to the next pipeline.
# Skipped pipeline #200 due to time out. Continuing to the next pipeline.
# Skipped pipeline #207 due to time out. Continuing to the next pipeline.
# Skipped pipeline #213 due to time out. Continuing to the next pipeline.
# Skipped pipeline #220 due to time out. Continuing to the next pipeline.
# Skipped pipeline #233 due to time out. Continuing to the next pipeline.
#
# Generation 1 - Current Pareto front scores:
#
# -1	0.8340499365842117	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=1 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 56.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=1 manhattan was provided as affinity. Ward can only work with euclidean distances..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=1 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 73.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# Skipped pipeline #241 due to time out. Continuing to the next pipeline.
# Skipped pipeline #295 due to time out. Continuing to the next pipeline.
# Skipped pipeline #299 due to time out. Continuing to the next pipeline.
# Skipped pipeline #308 due to time out. Continuing to the next pipeline.
#
# Generation 2 - Current Pareto front scores:
#
# -1	0.840499460571596	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.6500000000000001, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=3, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 73.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# Skipped pipeline #342 due to time out. Continuing to the next pipeline.
# Skipped pipeline #344 due to time out. Continuing to the next pipeline.
# Skipped pipeline #356 due to time out. Continuing to the next pipeline.
# Skipped pipeline #376 due to time out. Continuing to the next pipeline.
# Skipped pipeline #399 due to time out. Continuing to the next pipeline.
# Skipped pipeline #404 due to time out. Continuing to the next pipeline.
# Skipped pipeline #411 due to time out. Continuing to the next pipeline.
# Skipped pipeline #416 due to time out. Continuing to the next pipeline.
# Skipped pipeline #420 due to time out. Continuing to the next pipeline.
# Skipped pipeline #426 due to time out. Continuing to the next pipeline.
# Skipped pipeline #428 due to time out. Continuing to the next pipeline.
# Skipped pipeline #431 due to time out. Continuing to the next pipeline.
# Skipped pipeline #437 due to time out. Continuing to the next pipeline.
# Skipped pipeline #439 due to time out. Continuing to the next pipeline.
# Skipped pipeline #442 due to time out. Continuing to the next pipeline.
# Skipped pipeline #448 due to time out. Continuing to the next pipeline.
# Skipped pipeline #450 due to time out. Continuing to the next pipeline.
# Skipped pipeline #453 due to time out. Continuing to the next pipeline.
# Skipped pipeline #455 due to time out. Continuing to the next pipeline.
#
# Generation 3 - Current Pareto front scores:
#
# -1	0.840499460571596	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.6500000000000001, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=3, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 [16:40:28] /Users/runner/miniforge3/conda-bld/xgboost_1607604592557/work/src/learner.cc:567: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x000000011c72d23e dmlc::LogMessageFatal::~LogMessageFatal() + 110
#   [bt] (1) 2   libxgboost.dylib                    0x000000011c7e8173 xgboost::LearnerConfiguration::ConfigureNumFeatures() + 963
#   [bt] (2) 3   libxgboost.dylib                    0x000000011c7ddd51 xgboost::LearnerConfiguration::Configure() + 1041
#   [bt] (3) 4   libxgboost.dylib                    0x000000011c7de2e7 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 119
#   [bt] (4) 5   libxgboost.dylib                    0x000000011c731e5c XGBoosterUpdateOneIter + 156
#   [bt] (5) 6   libffi.6.dylib                      0x0000000101afd934 ffi_call_unix64 + 76
#   [bt] (6) 7   ???                                 0x00007ffeeed36f40 0x0 + 140732905254720
#
# .
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 90.
# _pre_test decorator: _random_mutation_operator: num_test=0 manhattan was provided as affinity. Ward can only work with euclidean distances..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 [16:40:33] /Users/runner/miniforge3/conda-bld/xgboost_1607604592557/work/src/learner.cc:567: Check failed: mparam_.num_feature != 0 (0 vs. 0) : 0 feature is supplied.  Are you using raw Booster interface?
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x000000011c72d23e dmlc::LogMessageFatal::~LogMessageFatal() + 110
#   [bt] (1) 2   libxgboost.dylib                    0x000000011c7e8173 xgboost::LearnerConfiguration::ConfigureNumFeatures() + 963
#   [bt] (2) 3   libxgboost.dylib                    0x000000011c7ddd51 xgboost::LearnerConfiguration::Configure() + 1041
#   [bt] (3) 4   libxgboost.dylib                    0x000000011c7de2e7 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 119
#   [bt] (4) 5   libxgboost.dylib                    0x000000011c731e5c XGBoosterUpdateOneIter + 156
#   [bt] (5) 6   libffi.6.dylib                      0x0000000101afd934 ffi_call_unix64 + 76
#   [bt] (6) 7   ???                                 0x00007ffeeed36f40 0x0 + 140732905254720
#
# .
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29']
# expected V8, V7, V10, V3, V17, V6, V16, V21, V14, V15, V19, V12, Amount, V11, V1, V13, V23, V28, V2, V26, V25, V20, V9, V4, Time, V27, V24, V22, V5, V18 in input data
# training data did not have the following fields: f28, f6, f27, f14, f15, f4, f7, f29, f12, f0, f5, f13, f9, f26, f16, f18, f24, f25, f11, f2, f8, f23, f3, f22, f17, f19, f10, f20, f21, f1.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #471 due to time out. Continuing to the next pipeline.
# Skipped pipeline #486 due to time out. Continuing to the next pipeline.
# Skipped pipeline #516 due to time out. Continuing to the next pipeline.
# Skipped pipeline #519 due to time out. Continuing to the next pipeline.
# Skipped pipeline #522 due to time out. Continuing to the next pipeline.
# Skipped pipeline #525 due to time out. Continuing to the next pipeline.
# Skipped pipeline #530 due to time out. Continuing to the next pipeline.
# Skipped pipeline #535 due to time out. Continuing to the next pipeline.
# Skipped pipeline #549 due to time out. Continuing to the next pipeline.
# Skipped pipeline #554 due to time out. Continuing to the next pipeline.
# Skipped pipeline #562 due to time out. Continuing to the next pipeline.
#
# Generation 4 - Current Pareto front scores:
#
# -1	0.842604927161674	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 76.
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 73.
# _pre_test decorator: _random_mutation_operator: num_test=1 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=2 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=0 cosine was provided as affinity. Ward can only work with euclidean distances..
# _pre_test decorator: _random_mutation_operator: num_test=0 X contains negative values..
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# _pre_test decorator: _random_mutation_operator: num_test=1 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Negative values in data passed to MultinomialNB (input X).
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #576 due to time out. Continuing to the next pipeline.
# Skipped pipeline #578 due to time out. Continuing to the next pipeline.
# Skipped pipeline #584 due to time out. Continuing to the next pipeline.
# Skipped pipeline #589 due to time out. Continuing to the next pipeline.
# Skipped pipeline #591 due to time out. Continuing to the next pipeline.
# Skipped pipeline #595 due to time out. Continuing to the next pipeline.
# Skipped pipeline #610 due to time out. Continuing to the next pipeline.
# Skipped pipeline #617 due to time out. Continuing to the next pipeline.
# Skipped pipeline #630 due to time out. Continuing to the next pipeline.
# Skipped pipeline #632 due to time out. Continuing to the next pipeline.
# Skipped pipeline #646 due to time out. Continuing to the next pipeline.
# Skipped pipeline #649 due to time out. Continuing to the next pipeline.
# Skipped pipeline #658 due to time out. Continuing to the next pipeline.
# Skipped pipeline #663 due to time out. Continuing to the next pipeline.
# Skipped pipeline #671 due to time out. Continuing to the next pipeline.
# Skipped pipeline #679 due to time out. Continuing to the next pipeline.
# Skipped pipeline #682 due to time out. Continuing to the next pipeline.
#
# Generation 5 - Current Pareto front scores:
#
# -1	0.842604927161674	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.9500000000000001, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=6, ExtraTreesClassifier__n_estimators=100)
# Runtime of the program is 1583331470.5374124 minutes

# %%
# Al menos 25 hs para concluir cada modelo
print(f"Runtime of the program is {(end - start)/(60*60)} horas")
# Out:
# Runtime of the program is 25.286777462760607 horas

# %%
#Generamos la instancia de predicciones
pred=tpot_3.predict(df)

#Evaluamos el desempeño
tpot_3.score(x_test, y_test)
print(tpot_3.score(x_test, y_test))
print(confusion_matrix(target, pred))

print(classification_report(target, pred))
# Out:
# 0.8928571428571429
# [[282501     16]
#  [    78    387]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    282517
#            1       0.96      0.83      0.89       465
#
#     accuracy                           1.00    282982
#    macro avg       0.98      0.92      0.95    282982
# weighted avg       1.00      1.00      1.00    282982

# %% [markdown]
# The fourth model increases indeed the score, but it does not much better than setting subsample to 1.

# %%
y_score=np.array(pred)
y_score
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test_1=np.array(y_test)
y_test_1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#Precision Recall curve
average_precision = average_precision_score(y_test_1, y_score)
#disp = plot_precision_recall_curve(tpot, x_test, y_test)
#disp.ax_.set_title('2-class Precision-Recall curve: '
#                   'AP={0:0.2f}'.format(average_precision))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-2dba2fcb997f> in <module>
#       1 #Precision Recall curve
# ----> 2 average_precision = average_precision_score(y_test_1, y_score)
#       3 #disp = plot_precision_recall_curve(tpot, x_test, y_test)
#       4 #disp.ax_.set_title('2-class Precision-Recall curve: '
#       5 #                   'AP={0:0.2f}'.format(average_precision))
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     214     average_precision = partial(_binary_uninterpolated_average_precision,
#     215                                 pos_label=pos_label)
# --> 216     return _average_binary_score(average_precision, y_true, y_score,
#     217                                  average, sample_weight=sample_weight)
#     218
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_uninterpolated_average_precision(y_true, y_score, pos_label, sample_weight)
#     195     def _binary_uninterpolated_average_precision(
#     196             y_true, y_score, pos_label=1, sample_weight=None):
# --> 197         precision, recall, _ = precision_recall_curve(
#     198             y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     199         # Return the step function integral
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in precision_recall_curve(y_true, probas_pred, pos_label, sample_weight)
#     673
#     674     """
# --> 675     fps, tps, thresholds = _binary_clf_curve(y_true, probas_pred,
#     676                                              pos_label=pos_label,
#     677                                              sample_weight=sample_weight)
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     539         raise ValueError("{0} format is not supported".format(y_type))
#     540
# --> 541     check_consistent_length(y_true, y_score, sample_weight)
#     542     y_true = column_or_1d(y_true)
#     543     y_score = column_or_1d(y_score)
#
# ~/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [70746, 282982]
